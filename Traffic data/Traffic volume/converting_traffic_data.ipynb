# %%
import sys, os
sys.path.append(os.path.dirname(os.getcwd()))
from db_connection import start_engine

engine = start_engine()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys, os
#       2 sys.path.append(os.path.dirname(os.getcwd()))
# ----> 3 from db_connection import start_engine
#       5 engine = start_engine()
#
# ModuleNotFoundError: No module named 'db_connection'
